# %%
# Import all required libraries
from langchain_classic.chains import create_history_aware_retriever, create_retrieval_chain
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_chroma import Chroma
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_groq import ChatGroq
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader
import os
from dotenv import load_dotenv

# %%
# Load environment variables from .env file
load_dotenv()
os.environ["HUGGINGFACE_HUB_TOKEN"] = os.getenv("HUGGINGFACE_HUB_TOKEN")

print("Imports completed successfully")
# Out:
# Imports completed successfully

# %%
# Initialize the embedding model (converts text to vectors)
embeddings = HuggingFaceEmbeddings(model_name='all-MiniLM-L6-v2')
print("Embeddings model loaded")
# Out:
# Embeddings model loaded

# %%
# Initialize the LLM (Large Language Model) for generating responses
llm = ChatGroq(model_name="llama-3.1-8b-instant")
print("LLM initialized")
# Out:
# LLM initialized

# %%
# Load PDF document(s)
# NOTE: Change this path to your actual PDF file
pdf_path = r"D:\Projects\RAG QA Chatbot\data\pdf2.pdf"

# %%
documents = []
loader = PyPDFLoader(pdf_path)
docs = loader.load()
documents.extend(docs)
print(f"✓ Loaded {len(documents)} pages from PDF")
# Out:
# ✓ Loaded 448 pages from PDF

# %%
documents[10]
# Out:
# Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.2 (Macintosh)', 'creationdate': '2025-05-14T15:09:41+02:00', 'moddate': '2025-06-10T11:11:17+02:00', 'title': 'UN Human Rights Report 2024', 'trapped': '/False', 'source': 'D:\\Projects\\RAG QA Chatbot\\data\\pdf2.pdf', 'total_pages': 448, 'page': 10, 'page_label': '11'}, page_content='11\nOverviewMandated by General Assembly resolution 48/141, \nUN Human Rights’ responsibilities include \nthe promotion and protection of the effective \nenjoyment by all, of all civil, cultural, economic, \npolitical and social rights, taking an active role in \naddressing challenges to the full realization of all \nhuman rights and preventing the continuation of \nhuman rights violations throughout the world. To \nthis end, UN Human Rights engages all govern -\nments in dialogue regarding the implementation \nof its mandate, with a view to securing respect for \nall human rights. It provides advisory services, \ntechnical and financial assistance at the request \nof the States and, where appropriate, supports \nactions and programmes in the field of human \nrights. Further, it strengthens international co -\noperation for the promotion and protection of \nall human rights and coordinates human rights \nactivities throughout the United Nations system, \nincluding through education and public informa-\ntion programmes.\nThe High Commissioner for Human Rights is \nthe principal human rights official of the United \nNations and is appointed by the General Assembly \nfor a fixed term of four years, with the possibili-\nty of one term renewal. Since October 2022, UN \nHuman Rights is led by the High Commissioner \nfor Human Rights, Volker Türk, with the support \nof the Deputy High Commissioner, Nada Al-\nNashif, and the Assistant Secretary-General for \nHuman Rights, Ilze Brands Kehris, who heads the \nNew York Office.\nUN Human Rights Report 2024')

# %%
# Split documents into smaller chunks for better retrieval
# chunk_size: Maximum size of each chunk (in characters)
# chunk_overlap: Overlap between chunks to maintain context
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, 
    chunk_overlap=200
)
splits = text_splitter.split_documents(documents)
print(f"✓ Split into {len(splits)} chunks")
# Out:
# ✓ Split into 1683 chunks

# %%
splits[10]
# Out:
# Document(metadata={'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.2 (Macintosh)', 'creationdate': '2025-05-14T15:09:41+02:00', 'moddate': '2025-06-10T11:11:17+02:00', 'title': 'UN Human Rights Report 2024', 'trapped': '/False', 'source': 'D:\\Projects\\RAG QA Chatbot\\data\\pdf2.pdf', 'total_pages': 448, 'page': 6, 'page_label': '6'}, page_content='in national censuses and surveys and land resti -\ntution policies. In Zambia, following our study \non the rights to food and education, the Govern-\nment significantly expanded its School Feeding \nProgramme. In South Africa, we made recommen-\ndations to update environmental regulations.\nIn Liberia, we provided technical and financial \nbacking to the Government’s National Action Plan \non Business and Human Rights – the fourth on the \nAfrican continent. In Haiti, we provided advice \nto the Multinational Security Support Mission \non implementing the Mission’s human rights \ncompliance mechanism and on preventing and \nresponding to any form of misconduct involving \nthe Mission’s personnel.\nIn the Gambia and Somalia, my Office suc -\ncessfully advocated for legal protection against \ngender-based discrimination and violence, \nincluding female genital mutilation. In Panama, \nour technical support contributed to identifying \nabuses against migrants and refugees, including')

# %%
# Create a vector database from document chunks
# This allows semantic search based on meaning, not just keywords
vectorstore = Chroma.from_documents(
    documents=splits, 
    embedding=embeddings
)
print("Vector store created")
# Out:
# Vector store created

# %%
# Create a retriever that will fetch relevant chunks for questions
retriever = vectorstore.as_retriever()
print("Retriever ready")
# Out:
# Retriever ready

# %%
# Dictionary to store chat histories for different sessions
# In Jupyter, this persists for the entire notebook session
store = {}

def get_session_history(session_id: str) -> BaseChatMessageHistory:
    """
    Retrieves or creates a chat history for a given session.
    
    Args:
        session_id: Unique identifier for the conversation session
    
    Returns:
        ChatMessageHistory object containing the conversation history
    """
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]

print("Session history management setup complete")
# Out:
# Session history management setup complete

# %%
# This chain reformulates questions based on chat history
# Example: If user asks "What about its benefits?" after asking about solar panels,
# it reformulates to "What are the benefits of solar panels?"

context_q_sys_prompt = (
    """Given a chat history and the latest user question 
    which might reference context in the chat history, formulate a standalone 
    question which can be understood without the chat history. Do NOT answer the 
    question, just reformulate if required and otherwise return as is."""
)
context_prompt = ChatPromptTemplate.from_messages([
    ("system", context_q_sys_prompt),
    MessagesPlaceholder("chat_history"),
    ("human", "{input}"),
])

# %%
# Create the history-aware retriever
history_aware_retriever = create_history_aware_retriever(
    llm, 
    retriever, 
    context_prompt
)
print("History-aware retriever created")
# Out:
# History-aware retriever created

# %%
# This chain takes the retrieved context and generates an answer

sys_prompt = (
    """You are an assistant for question-answering-tasks.
    Use the following peices of retrieved context to answer the question.
    If you don't know the answer, say that you don't know. Use three sentences
    at maximum and keep the answer concise.\n\n {context}"""
)
qa_prompt = ChatPromptTemplate.from_messages(
    [
    ("system", sys_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)

# %%
# Create the question-answer chain
question_answer_chain = create_stuff_documents_chain(llm, qa_prompt)
print("QA chain created")
# Out:
# QA chain created

# %%
# Combine retrieval and QA into a single chain
rag_chain = create_retrieval_chain(
    history_aware_retriever, 
    question_answer_chain
)

# %%
# Wrap the chain with message history management
conv_rag_chain = RunnableWithMessageHistory(
    rag_chain,
    get_session_history,
    input_messages_key="input",
    history_messages_key="chat_history",  # Fixed: was "chathistory"
    output_messages_key="answer"
)
print("Complete conversational RAG chain ready")
print("\n" + "="*60)
print("Setup complete! You can now ask questions.")
print("="*60 + "\n")
# Out:
# Complete conversational RAG chain ready
#
# ============================================================
# Setup complete! You can now ask questions.
# ============================================================

# %%
def ask_question(question, session_id="default_session"):
    """
    Ask a question to the RAG chatbot.
    
    Args:
        question: Your question as a string
        session_id: Session identifier (use same ID to maintain conversation context)
    
    Returns:
        Dictionary containing the answer and other metadata
    """
    # Invoke the conversational RAG chain
    response = conv_rag_chain.invoke(
        {"input": question},
        config={"configurable": {"session_id": session_id}},
    )
    
    # Display the answer
    print(f"\n📝 Question: {question}")
    print(f"💡 Answer: {response['answer']}\n")
    
    # Optionally show the chat history
    session_history = get_session_history(session_id)
    print(f"📚 Total messages in history: {len(session_history.messages)}")
    
    return response

# %%
# Now you can ask questions! Run this cell multiple times with different questions

# Example 1: First question
#ask_question("What is this document about?")

# Example 2: Follow-up question (uses context from previous question)
#ask_question("Can you elaborate on that?")


# Example 3: Checking if context is maintained.
#ask_question("What was the question i just asked?")

# Example 4: Another question
#ask_question("Tell me about the various kinds of turmoils that can hamper human right?")

# Example 5: Another question
#ask_question("What are the various funds allocated for these purposes?")

# Example 5: Another question
ask_question("Funds Administered by UN HUMAN RIGHTS")
# Out:
# 📝 Question: Funds Administered by UN HUMAN RIGHTS
# 💡 Answer: According to the document, the UN Human Rights Office administers nine trust funds and three special funds, including:
#
# 1. The United Nations Trust Fund for the Support of the Activities of the High Commissioner for Human Rights
# 2. The United Nations Voluntary Trust Fund on Contemporary Forms of Slavery
# 3. The United Nations Voluntary Fund for Victims of Torture
# 4. The Human Rights Up Front Programme and other funds.
#
# 📚 Total messages in history: 14
# {'input': 'Funds Administered by UN HUMAN RIGHTS',
#  'chat_history': [HumanMessage(content='What is this document about?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='This document appears to be a report from the UN Human Rights Office (OHCHR) detailing their activities and achievements in a specific region, including providing technical assistance, supporting the preparation of human rights reports, and engaging with governments and civil society organizations.', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='What is this document about?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='This document is about the activities and accomplishments of the United Nations Human Rights Office (OHCHR) in a particular region, highlighting their efforts to promote and protect human rights.', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Can you elaborate on that?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='The document describes the work of the UN Human Rights Office (OHCHR) in various areas, including strengthening human rights work, providing training and support, and engaging with governments and civil society organizations to promote and protect human rights.', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='What was the question i just asked?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='You asked me to elaborate on my previous answer.', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='Tell me about the various kinds of turmoils that can hamper human right?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='According to the document, human rights can be hampered by various kinds of turmoils, including:\n\n- Violence and homicide rates linked to organized crime and drug trafficking\n- Insecurity\n- Repressive policies\n- Socioeconomic difficulties\n- Systemic inequalities\n- Severe environmental disasters, including climate-related events\n- State of emergency measures\n- Restrictive migration measures\n- High levels of discrimination, including against minority communities and migrants.', additional_kwargs={}, response_metadata={}),
#   HumanMessage(content='What are the various funds allocated for these purposes?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content="I don't know the specific funds allocated for these purposes.", additional_kwargs={}, response_metadata={})],
#  'context': [Document(id='ab432516-8f8b-4743-9e40-0c41df7474ca', metadata={'title': 'UN Human Rights Report 2024', 'page': 90, 'producer': 'Adobe PDF Library 17.0', 'source': 'D:\\Projects\\RAG QA Chatbot\\data\\pdf2.pdf', 'moddate': '2025-06-10T11:11:17+02:00', 'page_label': '95', 'creationdate': '2025-05-14T15:09:41+02:00', 'trapped': '/False', 'creator': 'Adobe InDesign 20.2 (Macintosh)', 'total_pages': 448}, page_content='Funding\n94\nUN Human Rights Report 2024\nFUNDS ADMINISTERED \nBY UN HUMAN RIGHTS\nVoluntary contributions in support of UN Human Rights \nare channelled and managed through nine trust funds and \nthree special funds, which are not trust funds as defined by \nthe United Nations Financial Regulations and Rules.\nAdditional financial information related to these funds can be \nfound in the extrabudgetary income and expenditure report \nfor 2024 (pages 114-117 and page 430 of the online report).\nUNITED NATIONS TRUST FUND FOR THE \nSUPPORT OF THE ACTIVITIES OF THE HIGH \nCOMMISSIONER FOR HUMAN RIGHTS\nIn 1993, the United Nations Trust Fund for the \nSupport of the Activities of the High Commis -\nsioner for Human Rights was established by \nthe Secretary-General to supplement regular \nbudgetary resources as a general funding pool. \nIt is the largest fund administered by UN Human \nRights. In 2024, the Trust Fund managed 83.5 \nper cent of all extrabudgetary funds, including'),
#   Document(id='0016cc42-0f95-428a-9d47-6856cc7afeb0', metadata={'source': 'D:\\Projects\\RAG QA Chatbot\\data\\pdf2.pdf', 'moddate': '2025-06-10T11:11:17+02:00', 'trapped': '/False', 'producer': 'Adobe PDF Library 17.0', 'creationdate': '2025-05-14T15:09:41+02:00', 'creator': 'Adobe InDesign 20.2 (Macintosh)', 'total_pages': 448, 'title': 'UN Human Rights Report 2024', 'page_label': '335', 'page': 328}, page_content='strengthens strategies for OHCHR’s engage -\nment on the ground. GLO contributes to the \nUN’s broader efforts related to the three United \nNations pillars, namely, human rights, peace and \nsecurity and development. This is accomplished \nthrough the integration of human rights across and \ninto all pillars and the mainstreaming of human \nrights-based peacebuilding and programming for \nsustainable development.\nGLO supports the implementation of specific \nOHCHR mandates of the HRC and the General \nAssembly regarding monitoring and public \nreporting on human rights issues and offers \ntechnical assistance and cooperation. This includes \nsupport for the HRC’s special procedures country \nmandates and the establishment of and support \nfor the international commissions of inquiry \n(COIs), fact-finding missions and investigations \nthat are mandated by the Council. GLO leads the \nimplementation of the Humanitarian Strategy for \nOHCHR. It also administers the Voluntary Fund'),
#   Document(id='eb0417ec-2bc5-45a1-8d77-9c87650de0f0', metadata={'page': 104, 'title': 'UN Human Rights Report 2024', 'source': 'D:\\Projects\\RAG QA Chatbot\\data\\pdf2.pdf', 'creator': 'Adobe InDesign 20.2 (Macintosh)', 'page_label': '109', 'producer': 'Adobe PDF Library 17.0', 'creationdate': '2025-05-14T15:09:41+02:00', 'trapped': '/False', 'total_pages': 448, 'moddate': '2025-06-10T11:11:17+02:00'}, page_content='10,500 slavery survivors.\nFor the first time, on 22 November, the Trust Fund \nhosted an on-site project visit to enable funding \npartners to witness the impacts of their support. \nThe visit, organized by OHCHR, was held at the \nOpen Gate/La Strada premises and shelter for \nvictims of human trafficking, in Skopje, North \nMacedonia. The Board of Trustee members from \nAustralia, Germany, Greece, Saudi Arabia, the \nUnited Kingdom and the United States of America \nengaged with stakeholders and learned how the \nUN Human Rights provides joint secretariat \nsupport for two grant-making funds, namely, the \nUnited Nations Voluntary Trust Fund on Contem-\nporary Forms of Slavery and the United Nations \nVoluntary Fund for Victims of Torture. Together, \nthey are known as the UN Human Rights Hu -\nmanitarian Funds. They were established by the \nGeneral Assembly, with the purpose of providing \ndirect assistance and rehabilitation to individu -\nals whose rights have been violated in the context'),
#   Document(id='9a731c92-87f5-4136-82fa-4c320c801ebf', metadata={'source': 'D:\\Projects\\RAG QA Chatbot\\data\\pdf2.pdf', 'page_label': '118', 'moddate': '2025-06-10T11:11:17+02:00', 'title': 'UN Human Rights Report 2024', 'creationdate': '2025-05-14T15:09:41+02:00', 'total_pages': 448, 'page': 113, 'producer': 'Adobe PDF Library 17.0', 'creator': 'Adobe InDesign 20.2 (Macintosh)', 'trapped': '/False'}, page_content='Total: Other trust funds 15,380,900 14,242,635 \nOther expenditure and adjustments not reported above -   (236,505)\nGrand total 346,557,532 2 79, 2 87, 7 72  \na Includes Human Rights Up Front Programme; support to digital transformation of UN Human Rights; OHCHR’s Task Forces on Economic, Social and Cultural \nRights (ESCRs); Sustainable Development Goals (SDGs) and Prevention.')],
#  'answer': 'According to the document, the UN Human Rights Office administers nine trust funds and three special funds, including:\n\n1. The United Nations Trust Fund for the Support of the Activities of the High Commissioner for Human Rights\n2. The United Nations Voluntary Trust Fund on Contemporary Forms of Slavery\n3. The United Nations Voluntary Fund for Victims of Torture\n4. The Human Rights Up Front Programme and other funds.'}

# %%
# Run this cell anytime to see the full conversation history
def show_history(session_id="default_session"):
    """Display the full chat history for a session."""
    session_history = get_session_history(session_id)
    print(f"\n{'='*60}")
    print(f"CHAT HISTORY (Session: {session_id})")
    print(f"{'='*60}\n")
    
    for i, message in enumerate(session_history.messages, 1):
        role = "🧑 Human" if message.type == "human" else "🤖 Assistant"
        print(f"{role}: {message.content}\n")
    
    if len(session_history.messages) == 0:
        print("No messages yet.")
    
    print(f"{'='*60}\n")


show_history()
# Out:
# ============================================================
# CHAT HISTORY (Session: default_session)
# ============================================================
#
# 🧑 Human: What is this document about?
#
# 🤖 Assistant: This document appears to be a report from the UN Human Rights Office (OHCHR) detailing their activities and achievements in a specific region, including providing technical assistance, supporting the preparation of human rights reports, and engaging with governments and civil society organizations.
#
# 🧑 Human: What is this document about?
#
# 🤖 Assistant: This document is about the activities and accomplishments of the United Nations Human Rights Office (OHCHR) in a particular region, highlighting their efforts to promote and protect human rights.
#
# 🧑 Human: Can you elaborate on that?
#
# 🤖 Assistant: The document describes the work of the UN Human Rights Office (OHCHR) in various areas, including strengthening human rights work, providing training and support, and engaging with governments and civil society organizations to promote and protect human rights.
#
# 🧑 Human: What was the question i just asked?
#
# 🤖 Assistant: You asked me to elaborate on my previous answer.
#
# 🧑 Human: Tell me about the various kinds of turmoils that can hamper human right?
#
# 🤖 Assistant: According to the document, human rights can be hampered by various kinds of turmoils, including:
#
# - Violence and homicide rates linked to organized crime and drug trafficking
# - Insecurity
# - Repressive policies
# - Socioeconomic difficulties
# - Systemic inequalities
# - Severe environmental disasters, including climate-related events
# - State of emergency measures
# - Restrictive migration measures
# - High levels of discrimination, including against minority communities and migrants.
#
# 🧑 Human: What are the various funds allocated for these purposes?
#
# 🤖 Assistant: I don't know the specific funds allocated for these purposes.
#
# 🧑 Human: Funds Administered by UN HUMAN RIGHTS
#
# 🤖 Assistant: According to the document, the UN Human Rights Office administers nine trust funds and three special funds, including:
#
# 1. The United Nations Trust Fund for the Support of the Activities of the High Commissioner for Human Rights
# 2. The United Nations Voluntary Trust Fund on Contemporary Forms of Slavery
# 3. The United Nations Voluntary Fund for Victims of Torture
# 4. The Human Rights Up Front Programme and other funds.
#
# ============================================================

# %%
# Run this cell to start a fresh conversation
def reset_conversation(session_id="default_session"):
    """Clear the chat history for a session."""
    if session_id in store:
        del store[session_id]
        print(f"✓ Conversation reset for session: {session_id}")
    else:
        print(f"No conversation found for session: {session_id}")


reset_conversation()
# Out:
# ✓ Conversation reset for session: default_session
